# %% [markdown]
# # Homework 3: Pandas data analysis

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Kaitlyn Watson </p>

# %% [markdown]
# # __CMSE  201 &ndash; Spring 2022__
#
# <img src="https://cmse.msu.edu/sites/_cmse/assets/Image/image002.jpg"
#      alt="CMSE Logo"
#      align="right"
#      height="100"
#      width="100" />
#
#
#
# ## Learning Goals
#
# * Load data into notebooks using Pandas
# * Determine the components of the data
# * Make meaningful visual representations of the data
# * Draw conclusions from statistical analysis
#
# ___

# %% [markdown]
# ## Assignment instructions
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# **This assignment is due at 11:59pm on Friday, Feb. 25th**
#
# It should be uploaded into D2L Homework #3.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ## Grading
#
# - Academic integrity statement: 1 pt
# - Part 0: Revisit plotting in HW2: 6 pts
# - Part 1: Reading, Describing, and Cleaning the Data: 22 pts
# - Part 2: Data analysis: 21 pts
#
# **Total:** 50 pts

# %% [markdown]
# ## Academic integrity statement (1 point)
#
# In the markdown cell below, paste your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font>  I, Kaitlyn Watson, commit to furthering my education at Michigan State University with full integrity. It is important to me to practice academic honesty in my coursework in order to fully benefit from the learning material and reflect good work ethic to those around me. I am motivated by my future career goals to conduct myself with integrity in everything that I do. Furthermore, I am fully aware of the ethical standards that MSU has established in regards to integrity and I intend to follow them to the best of my ability.

# %% [markdown]
# Before we read in the data and begin working with it, let's import the libraries that we would typically use for this task. You can always come back to this cell and import additional libraries that you need.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline

# %% [markdown]
# ### Part 0: Revisit plotting in HW2 (6 total points)

# %% [markdown]
# In question 4 of HW2, we consider two equations that give the (x,y) points for values of k (ranging from 0 to 9000). When all 9000 points are plotted, you will see that it draws out a flower design.
#
# $x(k) = \mathrm{cos}\Big(\frac{14 \pi k}{9000}\Big)\Big(1-\frac{3}{4}\mathrm{sin}\Big(\frac{20\pi k}{9000}\Big)-\frac{1}{4}\mathrm{cos}\Big(\frac{60 \pi k}{9000}\Big)\Big)$
#
# $y(k) = \mathrm{sin}\Big(\frac{14 \pi k}{9000}\Big)\Big(1-\frac{3}{4}\mathrm{sin}\Big(\frac{20\pi k}{9000}\Big)-\frac{1}{4}\mathrm{cos}\Big(\frac{60 \pi k}{9000}\Big)\Big)$
#
# The goal here is to revisit this problem, and achieve the same purpose by using numpy arrary and functions. Now the code will be much shorter. (Note: in this question, you are not allowed to use `list` and you no longer need to define `draw_flower_points` function.)
#
# <font size=8 color="#009600">&#9998;</font> Do This - Write a piece of code to define `k` as a numpy array ranging from 0 to 9000 with 500 points. (2 points) Use `np.sin` and `np.cos` to define `x_k` and `y_k` as the corresponding numpy. (3 points) Then plot the final flower design. (1 point)

# %%
k=np.linspace(0,9000, 500)

x_k=np.cos((14*math.pi*k)/9000)*(1-(0.75*np.sin((20*math.pi*k)/9000))-(0.25*np.cos((60*np.pi*k)/9000)))
y_k=np.sin((14*np.pi*k)/9000)*(1-(0.75*np.sin((20*math.pi*k)/9000))-(0.25*np.cos((60*np.pi*k)/9000)))

plt.plot(x_k, y_k)
plt.xlabel(xlabel='x')
plt.ylabel(ylabel='y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Part 1: Reading, Describing, and Cleaning the Data (22 total points)

# %% [markdown]
# The United Nations compiles an annual publication called the [World Happiness Report](https://en.wikipedia.org/wiki/World_Happiness_Report) that ranks countries by the "happiness score" or "life ladder". These scores are based on a surveys of citizens of each country on a variety of factors such as:
# * Gross Domestic Product (GDP) per capita
# * Perceptions of social support
# * Life expectancy
# * Freedom of choice
#
# [Data from the UN](https://worldhappiness.report/) is available from 2005-2019, which we have downloaded in a `.csv` format. The survey has changed over time, so that some factors and questions have been omitted. So some of the data is incomplete or missing.
#
# ### 1.1 Read the data (4 points)
#
# <font size=8 color="#009600">&#9998;</font> Do This - Read in the survey data from `happiness_index.csv` into a DataFrame and print the `.head()` of the data, use `describe` to get a feel of this dataset.

# %%
happiness= pd.read_csv('happiness_index.csv')
happiness.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.144916        0.450662
# 1  Afghanistan  2009     4.401778            7.314788        0.552308
# 2  Afghanistan  2010     4.758381            7.421525        0.539075
# 3  Afghanistan  2011     3.831719            7.394349        0.521104
# 4  Afghanistan  2012     3.782938            7.480296        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.178993
# 1                         51.200001                      0.678896    0.201228
# 2                         51.599998                      0.600127    0.131578
# 3                         51.919998                      0.495901    0.173452
# 4                         52.240002                      0.530935    0.246943
#
#    Perceptions of corruption  Positive affect  ...  \
# ...

# %%
happiness.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1848.000000  1848.000000         1819.000000     1835.000000
# mean   2012.848485     5.445810            9.244531        0.811132
# std       3.962437     1.118989            1.168422        0.118987
# min    2005.000000     2.375092            6.456574        0.290184
# 25%    2010.000000     4.623136            8.309359        0.748296
# 50%    2013.000000     5.363165            9.407829        0.833975
# 75%    2016.000000     6.268130           10.209482        0.904574
# max    2019.000000     8.018934           11.728235        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1796.000000                   1817.000000
# mean                          63.169525                      0.738467
# std                            7.546524                      0.143059
# min                           32.299999                      0.257534
# ...

# %% [markdown]
# ### 1.2 Clean the data (8 total points)
#
# #### 1.2.1 Remove and track excess data (2 points)
#
# We need to remove the excess features that are not present in every year's data.
#
# <font size=8 color="#009600">&#9998;</font> Do This - Drop the columns that are not the following:
# * Country name
# * year
# * Life Ladder
# * Log GDP per capita
# * Social support
# * Healthy life expectancy at birth
# * Freedom to make life choices
# * Generosity
# * Perceptions of corruption
# * Positive affect
# * Negative affect
# * Confidence in national government
# * Democratic Quality
# * Delivery Quality
#
# Make sure to make a list of the columns that you dropped. This is important if you need to report what you didn't consider in the model. Print the `.head()` of the DataFrame after dropping the unneeded columns.

# %%
happiness_index=happiness[["Country name","year", "Life Ladder", "Log GDP per capita","Social support","Healthy life expectancy at birth", "Freedom to make life choices", "Generosity","Perceptions of corruption","Positive affect","Negative affect","Confidence in national government","Democratic Quality","Delivery Quality"]]
happiness_index.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.144916        0.450662
# 1  Afghanistan  2009     4.401778            7.314788        0.552308
# 2  Afghanistan  2010     4.758381            7.421525        0.539075
# 3  Afghanistan  2011     3.831719            7.394349        0.521104
# 4  Afghanistan  2012     3.782938            7.480296        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.178993
# 1                         51.200001                      0.678896    0.201228
# 2                         51.599998                      0.600127    0.131578
# 3                         51.919998                      0.495901    0.173452
# 4                         52.240002                      0.530935    0.246943
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
dropped_col=["GINI index (World Bank estimate)", "GINI index (World Bank estimate), average 2000-2017, unbalanced panel", "gini of household income reported in Gallup, by wp5-year", "Most people can be trusted,Gallup","Most people can be trusted, WVS round 1981-1984","Most people can be trusted, WVS round 1989-1993", "Most people can be trusted, WVS round 1994-1998","Most people can be trusted, WVS round 1999-2004" ,"Most people can be trusted, WVS round 2005-2009", "Most people can be trusted,WVS round 2010-2014"]
print(dropped_col)
# Out:
# ['GINI index (World Bank estimate)', 'GINI index (World Bank estimate), average 2000-2017, unbalanced panel', 'gini of household income reported in Gallup, by wp5-year', 'Most people can be trusted,Gallup', 'Most people can be trusted, WVS round 1981-1984', 'Most people can be trusted, WVS round 1989-1993', 'Most people can be trusted, WVS round 1994-1998', 'Most people can be trusted, WVS round 1999-2004', 'Most people can be trusted, WVS round 2005-2009', 'Most people can be trusted,WVS round 2010-2014']

# %% [markdown]
# #### 1.2.2 Focus on the 2018 data (3 points)
#
# Your data should include scores for a variety of years (2005-2019) for each country. Let's focus on a single year: 2018.
#
# <font size=8 color="#009600">&#9998;</font> Do This - Use mask to filter your data to focus only on the latest available data from 2018. Print the `.head()` of that DataFrame.

# %%
Year2018=happiness_index["year"]==2018
Data18=happiness_index[Year2018]
Data18.head()
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 10  Afghanistan  2018     2.694303            7.458603        0.507516
# 22      Albania  2018     5.004403            9.417863        0.683592
# 30      Algeria  2018     5.043086            9.538646        0.798651
# 48    Argentina  2018     5.792797            9.813678        0.899912
# 62      Armenia  2018     5.062449            9.124537        0.814449
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 10                         52.599998                      0.373536
# 22                         68.699997                      0.824212
# 30                         65.900002                      0.583381
# 48                         68.800003                      0.845895
# 62                         66.900002                      0.807644
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %% [markdown]
# #### 1.2.3 Missing data (3 points)
#
# Not all the countries have reported values for every feature. You should check if any countries have missing data. We could impute these missing data in a variety of ways, but instead to make our work a little simpler, we will simply drop a country if it has any missing data.
#
# <font size=8 color="#009600">&#9998;</font> Do This - Drop any country from the data that is missing data.

# %%
## your code here

happiness_index_18=Data18.dropna(axis = 0, how ='any', thresh = None, subset = None, inplace=False)

# %% [markdown]
# ### 1.3 Describe the data (10 points)
#
# Now that you have a cleaned data set, let's look into the data. We can start that by describing the data and making histograms of it.
#
# <font size=8 color="#009600">&#9998;</font> Do This - Focusing on the data collected in the survey (i.e., not the country name or year), *describe* the data by using the `describe` function in pandas. (2 points)

# %%
happiness_index_18.describe()
# Out:
#          year  Life Ladder  Log GDP per capita  Social support  \
# count   121.0   121.000000          121.000000      121.000000
# mean   2018.0     5.539629            9.301184        0.813747
# std       0.0     1.123867            1.178485        0.115870
# min    2018.0     2.694303            6.837319        0.503544
# 25%    2018.0     4.769377            8.263374        0.739355
# 50%    2018.0     5.513500            9.497988        0.845803
# 75%    2018.0     6.249419           10.264216        0.909807
# max    2018.0     7.858107           11.448219        0.965962
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                        121.000000                    121.000000
# mean                          64.520548                      0.782520
# std                            7.015459                      0.118026
# min                           48.200001                      0.373536
# ...

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do This - We can use numpy functions to verify what we have obtained in the description in the previous part. Define a Numpy array to be the same as the column of data corresponding to the feature 'Life Ladder'. Use Numpy functions to compute the mean and the standard deviation of this array. Does it agree with what you had from the previous question? (4 points)

# %%
Life_Ladder= happiness_index_18['Life Ladder'].to_numpy()
print("the mean of the life ladder is", np.mean(Life_Ladder))
print("the standard deviation of the life ladder is", np.std(Life_Ladder))
# Out:
# the mean of the life ladder is 5.539629473190082
# the standard deviation of the life ladder is 1.119213392470201

# %% [markdown]
# The mean and standard deviation I found using numpy functions match what I found using the decribe function.

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do This -Make histograms describing the distributions of all the features. (4 points)

# %%
happiness_index_18.hist("Life Ladder")
happiness_index_18.hist("Log GDP per capita")
happiness_index_18.hist("Social support")
happiness_index_18.hist("Healthy life expectancy at birth")
happiness_index_18.hist("Freedom to make life choices")
happiness_index_18.hist("Generosity")
happiness_index_18.hist("Perceptions of corruption")
happiness_index_18.hist("Positive affect")
happiness_index_18.hist("Negative affect")
happiness_index_18.hist("Confidence in national government")
happiness_index_18.hist("Democratic Quality")
happiness_index_18.hist("Delivery Quality")
# Out:
# array([[<AxesSubplot:title={'center':'Delivery Quality'}>]], dtype=object)

# %% [markdown]
# ## Part 2: Data analysis (21 total points)
#
# Now  we will analyze the cleaned dataset.
#
# ### 2.1 The ranking (12 points)
#
# The rankings of national happiness are based on a Cantril ladder survey. Nationally representative samples of respondents are asked to think of a ladder, with the best possible life for them being a 10, and the worst possible life being a 0.  This is represented by 'Life Ladder' in the dataset.
#
#
# <font size=8 color="#009600">&#9998;</font> Do This - Reorder the dataframe   according to descending values of the 'Life Ladder' score using `sort_values` (Refer to  (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html#pandas.DataFrame.sort_values). Which are the top 3 happiest  countries? (4 points)

# %%
sort_happiness_index18=happiness_index_18.sort_values(by=['Life Ladder'], ascending=False)
sort_happiness_index18
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 531       Finland  2018     7.858107           10.640223        0.962155
# 438       Denmark  2018     7.648786           10.772796        0.958219
# 1574  Switzerland  2018     7.508587           10.985619        0.930291
# 1168  Netherlands  2018     7.463097           10.815511        0.939443
# 1237       Norway  2018     7.444262           11.088910        0.965962
# ...           ...   ...          ...                 ...             ...
# 204      Botswana  2018     3.461366            9.712220        0.794936
# 1621     Tanzania  2018     3.445023            7.969772        0.675330
# 1003       Malawi  2018     3.334634            7.058997        0.527843
# 1819        Yemen  2018     3.057514            7.734108        0.789422
# 10    Afghanistan  2018     2.694303            7.458603        0.507516
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# The top 3 happiest contries in 2018 are Finland, Denmark, and Switzerland

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do This -  Replace the index of the sorted dataframe to be the ranking of the ranking of the country. (4 points)

# %%
sorted_happiness_index18=sort_happiness_index18.reset_index(drop=True)
sorted_happiness_index18
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0        Finland  2018     7.858107           10.640223        0.962155
# 1        Denmark  2018     7.648786           10.772796        0.958219
# 2    Switzerland  2018     7.508587           10.985619        0.930291
# 3    Netherlands  2018     7.463097           10.815511        0.939443
# 4         Norway  2018     7.444262           11.088910        0.965962
# ..           ...   ...          ...                 ...             ...
# 116     Botswana  2018     3.461366            9.712220        0.794936
# 117     Tanzania  2018     3.445023            7.969772        0.675330
# 118       Malawi  2018     3.334634            7.058997        0.527843
# 119        Yemen  2018     3.057514            7.734108        0.789422
# 120  Afghanistan  2018     2.694303            7.458603        0.507516
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do this - Use mask to find the United States in this ranking. What's the ranking of the U.S.? (4 points)

# %%
UnitedStates=sorted_happiness_index18["Country name"]=="United States"

country_masked =sorted_happiness_index18[UnitedStates]
country_masked
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 19  United States  2018     6.882685           10.927395        0.903856
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 19                         68.300003                      0.824607
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 19    0.113378                   0.709928         0.815383         0.292226
#
#     Confidence in national government  Democratic Quality  Delivery Quality
# 19                           0.313816            0.758395          1.482865

# %% [markdown]
# The ranking of the United States is 20

# %% [markdown]
# ### 2.2 Determining which features will matter (9 points)
#
# We want to understand what variables matters for people's happiness. We will do this by starting the correlation of the features with `Life Ladder`.
#
# <font size=8 color="#009600">&#9998;</font> Do this - Make   `scatter` plots of `Life Ladder` vs. all other features. (5 points)

# %%
plt.figure(1)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Log GDP per capita"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Log GDP per capita")

plt.figure(2)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Social support"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Social Support")

plt.figure(3)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Healthy life expectancy at birth"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Healthy life expectancy at birth")

plt.figure(4)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Freedom to make life choices"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Freedom to make life choices")

plt.figure(5)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Generosity"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Generosity")

plt.figure(6)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Perceptions of corruption"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Perceptions of Corruption")

plt.figure(7)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Positive affect"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Positive Affect")

plt.figure(8)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Negative affect"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Negative Affect ")

plt.figure(9)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Confidence in national government" ])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Confidence in national government")

plt.figure(10)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Democratic Quality"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Democratic Quality")

plt.figure(11)
plt.scatter(x=sorted_happiness_index18["Life Ladder"], y=sorted_happiness_index18["Delivery Quality"])
plt.xlabel(xlabel="Life Ladder")
plt.ylabel(ylabel="Delivery Quality")
# Out:
# Text(0, 0.5, 'Delivery Quality')

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do this -  Look at your plots, for each feature, is it correlated to `Life Ladder`? If so, is it positively or negatively correlated? Explain your reasoning (4 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Figure 1: There is a positive correlation between Life Ladder and Log GDP per capita. The points are grouped together representing a slight linear correlation in the positive x direction.
#
# Figure 2:There is a weaker correlation between Life Ladder and Social Support. However, the scatter plot still seems to visualize a positive correlation between the two variables.
#
# Figure 3: I would say there is a wea postive correlation between Life ladder and Healthy life expectancy at birth. The pointsa are relatively spread out, but still are trending in the positive x and y direction.
#
# Figure 4: I would say that the Life Ladder vs. Freedom to make life choices has a very week or non-existent correlation. The points are very spread apart and contain outliers, but have a slight trend in the postive x and y direction.
#
# Figure 5: There is no correlation between Life Ladder and Generosity. The points are scattered all over the plot and there are several outliers. No trend can be determined from the data.
#
# Figure 6: There seemes to be a slight negative correlation between Life ladder and Perception of corruption. The data points with hgiher Life Ladder values have a trend of decreasing in the y direction.
#
# Figure 7: There is no correlation between Life Ladder and Positive Affect. Similar to Figure 5, the points are scattered very far apart from one another and there are several outliers.
#
# Figure 8: There is either no/ or a slight negative correlation between life ladder and negative affect. The points are relatively far away from each other, but can be seen trending slightly in the negative y direction.
#
# Figure 9: There is no correlation between Life Ladder and Confidence in National government. This is the same reasoning for Figure 5 and Figure 7.
#
# Figure 10: There is a week positive correlation in the plot Life Ladder vs. Democratic Quality. As the Life Ladder values increase, the points on the graph group closer to together in the postive y direction.
#
# Figure 11: There is also a positive correlation between Life Ladder and Delivery Quality. There are several points grouped towards the middle of the plot, but the general trend is in the positive y direction.

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Homework Assignments" section, find the submission folder link for Homework #3, and upload it there.

# %% [markdown]
# &#169; Copyright Michigan State University Board of Trustees
